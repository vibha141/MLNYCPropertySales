# %% [markdown]
# <a href="https://colab.research.google.com/github/vibha141/MLNYCPropertySales/blob/main/NYC_PART_A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/nyc-rolling-sales_clean.csv')

# %%
df.head()
# Out:
#     NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 2  ALPHABET CITY  22 STORE BUILDINGS
# 3        CHELSEA  01 ONE FAMILY DWELLINGS
# 4        CHELSEA  01 ONE FAMILY DWELLINGS
#
#    TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                     2    387  153                        D9
# 1                     2    376   14                        C6
# 2                     4    390   34                        K4
# 3                     1    771   52                        A9
# 4                     1    772   29                        A4
#
#                   ADDRESS  ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 0     629 EAST 5TH STREET     10009                 24                 0
# 1     244 EAST 7TH STREET     10009                 24                 0
# 2            115 AVENUE C     10009                  0                 1
# ...

# %%
df["year of sale"] = df["SALE DATE"].str[:4]
df
# Out:
#         NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0      ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 1      ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 2      ALPHABET CITY  22 STORE BUILDINGS
# 3            CHELSEA  01 ONE FAMILY DWELLINGS
# 4            CHELSEA  01 ONE FAMILY DWELLINGS
# ...              ...                                          ...
# 42687        WOODROW  02 TWO FAMILY DWELLINGS
# 42688        WOODROW  02 TWO FAMILY DWELLINGS
# 42689        WOODROW  02 TWO FAMILY DWELLINGS
# 42690        WOODROW  22 STORE BUILDINGS
# 42691        WOODROW  35 INDOOR PUBLIC AND CULTURAL FACILITIES
#
#        TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                         2    387  153                        D9
# 1                         2    376   14                        C6
# 2                         4    390   34                        K4
# 3                         1    771   52                        A9
# ...

# %%
df.drop(["SALE DATE"],axis=1,inplace =True)

# %%
df.head()
# Out:
#     NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0  ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 1  ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 2  ALPHABET CITY  22 STORE BUILDINGS
# 3        CHELSEA  01 ONE FAMILY DWELLINGS
# 4        CHELSEA  01 ONE FAMILY DWELLINGS
#
#    TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                     2    387  153                        D9
# 1                     2    376   14                        C6
# 2                     4    390   34                        K4
# 3                     1    771   52                        A9
# 4                     1    772   29                        A4
#
#                   ADDRESS  ZIP CODE  RESIDENTIAL UNITS  COMMERCIAL UNITS  \
# 0     629 EAST 5TH STREET     10009                 24                 0
# 1     244 EAST 7TH STREET     10009                 24                 0
# 2            115 AVENUE C     10009                  0                 1
# ...

# %%
dummy_val = pd.get_dummies(df['TAX CLASS AT PRESENT'])

# %%
dummy_val
# Out:
#        1  2  3  4
# 0      0  1  0  0
# 1      0  1  0  0
# 2      0  0  0  1
# 3      1  0  0  0
# 4      1  0  0  0
# ...   .. .. .. ..
# 42687  1  0  0  0
# 42688  1  0  0  0
# 42689  1  0  0  0
# 42690  0  0  0  1
# 42691  0  0  0  1
#
# [42692 rows x 4 columns]

# %%
df
# Out:
#         NEIGHBORHOOD                      BUILDING CLASS CATEGORY  \
# 0      ALPHABET CITY  08 RENTALS - ELEVATOR APARTMENTS
# 1      ALPHABET CITY  09 COOPS - WALKUP APARTMENTS
# 2      ALPHABET CITY  22 STORE BUILDINGS
# 3            CHELSEA  01 ONE FAMILY DWELLINGS
# 4            CHELSEA  01 ONE FAMILY DWELLINGS
# ...              ...                                          ...
# 42687        WOODROW  02 TWO FAMILY DWELLINGS
# 42688        WOODROW  02 TWO FAMILY DWELLINGS
# 42689        WOODROW  02 TWO FAMILY DWELLINGS
# 42690        WOODROW  22 STORE BUILDINGS
# 42691        WOODROW  35 INDOOR PUBLIC AND CULTURAL FACILITIES
#
#        TAX CLASS AT PRESENT  BLOCK  LOT BUILDING CLASS AT PRESENT  \
# 0                         2    387  153                        D9
# 1                         2    376   14                        C6
# 2                         4    390   34                        K4
# 3                         1    771   52                        A9
# ...
